# %%
#Question 01

#Function for FULL_name
#It takes two arguments named first and last.
#It returns the full name by concatinationg both strings.
def fullname(first,last):
    return first+" "+last

#String_alternative function.
def string_alternative(Full_name):
    ans = ""
    for i in Full_name[::2]:
        ans+=i

    return ans

#Input for first name
First_name = input()

#Input for last name
Last_name = input()

Full_name = fullname(First_name,Last_name) #Function call which returns fullname
print(Full_name)

AlternameString = string_alternative(Full_name)
print(AlternameString)
# Out:
# Sai Krishna
# Jaswanth
# Sai Krishna Jaswanth
# SiKihaJsat

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Input_file = open("/content/drive/MyDrive/Colab Notebooks/input.txt", "r")
#Write the number of words count and split the data from input file
output_file = open("/content/drive/MyDrive/Colab Notebooks/output.txt", "w")

content = {}


for line in Input_file:
    output_file.write(line)
    new_l = line.split()
    for x in new_l:
        if(content.get(x)==None):
            content[x]=1
        else:
            content[x] = content[x] + 1

output_file.write(" Word_Count : ")
for key, value in content.items():
        output_file.write('%s:%s\n' % (key, value))
Input_file.close()
output_file.close()

# %%
#Input the size of the list
n = int(input())
#Empty list
l = []
#For loop which gives input into the list. List of hiehgts in inches.
for i in range(n):
    x = int(input())
    l.append(x)

#Empty output list
li = []
#For loop ehich takes the output into the list. List of heights in centimeters.
for i in range(n):
    li.append(l[i]*2.54)
    print(li[i])
# Out:
# 5
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d0c9774f34ce> in <cell line: 6>()
#       5 #For loop which gives input into the list. List of hiehgts in inches.
#       6 for i in range(n):
# ----> 7     x = int(input())
#       8     l.append(x)
#       9
#
# ValueError: invalid literal for int() with base 10: ''
